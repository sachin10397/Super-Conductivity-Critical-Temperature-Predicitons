# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(r"C:\Users\My\Desktop\Python\Super Conductivity Critical Temperature Predicitons\train.csv")

# %%
df.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   4         88.944468             57.862692
# 1                   5         92.729214             58.518416
# 2                   4         88.944468             57.885242
# 3                   4         88.944468             57.873967
# 4                   4         88.944468             57.840143
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0          66.361592              36.116612             1.181795
# 1          73.132787              36.396602             1.449309
# 2          66.361592              36.122509             1.181795
# 3          66.361592              36.119560             1.181795
# 4          66.361592              36.110716             1.181795
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                 1.062396          122.90607              31.794921
# 1                 1.057755          122.90607              36.161939
# 2                 0.975980          122.90607              35.741099
# 3                 1.022291          122.90607              33.768010
# 4                 1.129224          122.90607              27.848743
#
#    std_atomic_mass  ...  wtd_mean_Valence  gmean_Valence  wtd_gmean_Valence  \
# 0        51.968828  ...          2.257143       2.213364           2.219783
# 1        47.094633  ...          2.257143       1.888175           2.210679
# 2        51.968828  ...          2.271429       2.213364           2.232679
# 3        51.968828  ...          2.264286       2.213364           2.226222
# 4        51.968828  ...          2.242857       2.213364           2.206963
#
#    entropy_Valence  wtd_entropy_Valence  range_Valence  wtd_range_Valence  \
# 0         1.368922             1.066221              1           1.085714
# 1         1.557113             1.047221              2           1.128571
# 2         1.368922             1.029175              1           1.114286
# 3         1.368922             1.048834              1           1.100000
# 4         1.368922             1.096052              1           1.057143
#
#    std_Valence  wtd_std_Valence  critical_temp
# 0     0.433013         0.437059           29.0
# 1     0.632456         0.468606           26.0
# 2     0.433013         0.444697           19.0
# 3     0.433013         0.440952           22.0
# 4     0.433013         0.428809           23.0
#
# [5 rows x 82 columns]

# %%
df_x= df.iloc[:,1:81]
df_x.head()
# Out:
#    mean_atomic_mass  wtd_mean_atomic_mass  gmean_atomic_mass  \
# 0         88.944468             57.862692          66.361592
# 1         92.729214             58.518416          73.132787
# 2         88.944468             57.885242          66.361592
# 3         88.944468             57.873967          66.361592
# 4         88.944468             57.840143          66.361592
#
#    wtd_gmean_atomic_mass  entropy_atomic_mass  wtd_entropy_atomic_mass  \
# 0              36.116612             1.181795                 1.062396
# 1              36.396602             1.449309                 1.057755
# 2              36.122509             1.181795                 0.975980
# 3              36.119560             1.181795                 1.022291
# 4              36.110716             1.181795                 1.129224
#
#    range_atomic_mass  wtd_range_atomic_mass  std_atomic_mass  \
# 0          122.90607              31.794921        51.968828
# 1          122.90607              36.161939        47.094633
# 2          122.90607              35.741099        51.968828
# 3          122.90607              33.768010        51.968828
# 4          122.90607              27.848743        51.968828
#
#    wtd_std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0            53.622535  ...          2.25          2.257143       2.213364
# 1            53.979870  ...          2.00          2.257143       1.888175
# 2            53.656268  ...          2.25          2.271429       2.213364
# 3            53.639405  ...          2.25          2.264286       2.213364
# 4            53.588771  ...          2.25          2.242857       2.213364
#
#    wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0           2.219783         1.368922             1.066221              1
# 1           2.210679         1.557113             1.047221              2
# 2           2.232679         1.368922             1.029175              1
# 3           2.226222         1.368922             1.048834              1
# 4           2.206963         1.368922             1.096052              1
#
#    wtd_range_Valence  std_Valence  wtd_std_Valence
# 0           1.085714     0.433013         0.437059
# 1           1.128571     0.632456         0.468606
# 2           1.114286     0.433013         0.444697
# 3           1.100000     0.433013         0.440952
# 4           1.057143     0.433013         0.428809
#
# [5 rows x 80 columns]

# %%
df_y=df.iloc[:,81]
df_y.head()
# Out:
# 0    29.0
# 1    26.0
# 2    19.0
# 3    22.0
# 4    23.0
# Name: critical_temp, dtype: float64

# %%
z_data=df_x.apply(zscore)
z_data.head()
# Out:
#    mean_atomic_mass  wtd_mean_atomic_mass  gmean_atomic_mass  \
# 0          0.046733             -0.451651          -0.158850
# 1          0.174269             -0.432071           0.059368
# 2          0.046733             -0.450978          -0.158850
# 3          0.046733             -0.451314          -0.158850
# 4          0.046733             -0.452324          -0.158850
#
#    wtd_gmean_atomic_mass  entropy_atomic_mass  wtd_entropy_atomic_mass  \
# 0              -0.611819             0.044358                -0.003707
# 1              -0.604180             0.777430                -0.015267
# 2              -0.611658             0.044358                -0.218984
# 3              -0.611739             0.044358                -0.103615
# 4              -0.611980             0.044358                 0.162775
#
#    range_atomic_mass  wtd_range_atomic_mass  std_atomic_mass  \
# 0           0.133725              -0.053039         0.378186
# 1           0.133725               0.108900         0.134901
# 2           0.133725               0.093294         0.378186
# 3           0.133725               0.020128         0.378186
# 4           0.133725              -0.199372         0.378186
#
#    wtd_std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0             0.609240  ...     -0.907755         -0.752156      -0.805912
# 1             0.627122  ...     -1.147084         -0.752156      -1.116731
# 2             0.610928  ...     -0.907755         -0.740164      -0.805912
# 3             0.610084  ...     -0.907755         -0.746160      -0.805912
# 4             0.607550  ...     -0.907755         -0.764149      -0.805912
#
#    wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0          -0.711705         0.186292             0.035183      -0.837959
# 1          -0.719454         0.664971            -0.014779      -0.033011
# 2          -0.700728         0.186292            -0.062235      -0.837959
# 3          -0.706224         0.186292            -0.010538      -0.837959
# 4          -0.722618         0.186292             0.113627      -0.837959
#
#    wtd_range_Valence  std_Valence  wtd_std_Valence
# 0          -0.406166    -0.838372        -0.520070
# 1          -0.362352    -0.426866        -0.450821
# 2          -0.376957    -0.838372        -0.503304
# 3          -0.391562    -0.838372        -0.511524
# 4          -0.435376    -0.838372        -0.538178
#
# [5 rows x 80 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components
#         -9.25743600e-03,  1.20848547e-03, -3.51932674e-03],
#        [-3.56566468e+00,  7.31439223e-01,  3.10236995e+00, ...,
#         -6.22569656e-03,  4.85489428e-03, -5.47361898e-03],
#        ...,
#        [ 1.03770537e+01, -9.65676714e-01,  1.57343167e+00, ...,
#          3.07399389e-03,  7.65829524e-03,  1.38483576e-03],
#        [ 9.66384871e+00, -1.02065521e+00,  1.20468889e+00, ...,
#         -5.64019185e-03,  8.27700862e-03,  2.25492140e-03],
#        [ 3.83682173e+00,  1.54974310e+00, -1.86263343e+00, ...,
#          7.72205146e-03, -1.57495233e-03,  3.12582455e-03]])

# %%
pca = PCA(n_components=10)
principalComponents = pca.fit_transform(z_data)
principalComponents
# Out:
# array([[-3.74338612e+00,  6.71760494e-01,  3.01073351e+00, ...,
#         -2.20690217e-01, -3.95987733e-01,  2.00772547e-01],
#        [-4.52100723e+00, -3.80770277e-01,  1.65884420e+00, ...,
#          2.21076224e-01,  4.20832960e-01, -1.13916825e+00],
#        [-3.56566468e+00,  7.31439408e-01,  3.10237008e+00, ...,
#          7.88790257e-03, -5.05632489e-01,  1.62340381e-01],
#        ...,
#        [ 1.03770537e+01, -9.65677457e-01,  1.57343164e+00, ...,
#          5.92284437e-02, -7.19104497e-01, -3.68290180e-01],
#        [ 9.66384871e+00, -1.02065579e+00,  1.20468896e+00, ...,
#         -1.61586821e+00,  1.46799559e-01, -6.61753514e-02],
#        [ 3.83682174e+00,  1.54974211e+00, -1.86263401e+00, ...,
#          3.02662808e-01,  1.65307665e-01,  1.05403688e-01]])

# %%
features=z_data
label = np.array(df["critical_temp"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.2, random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor
DTClassifier= DecisionTreeRegressor (max_depth=35, min_samples_split =2)
DTClassifier.fit(X_train,y_train)
predicted_labels = DTClassifier.predict(X_test)
predicted_labels
# Out:
# array([78.35 , 77.   ,  9.086, ...,  6.   , 28.   , 23.6  ])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,predicted_labels)
# Out:
# 150.93703155436395

# %%
#for whole data
DTClassifier= DecisionTreeRegressor (max_depth=50, min_samples_split =2)
DTClassifier.fit(z_data,df_y)
predicted_labels = DTClassifier.predict(z_data)
predicted_labels
# Out:
# array([24.43166667, 26.5       , 28.16666667, ...,  1.98      ,
#         1.84      , 12.1       ])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(df_y,predicted_labels)
# Out:
# 18.514249538204826

# %%
pca = PCA(n_components=20)
principalComponents = pca.fit_transform(z_data)
principalComponents
# Out:
# array([[-3.74338612e+00,  6.71760435e-01,  3.01073344e+00, ...,
#         -2.27835023e-01, -1.41071840e-01, -3.27780896e-01],
#        [-4.52100723e+00, -3.80770572e-01,  1.65884411e+00, ...,
#         -4.47220248e-01,  3.94583456e-01,  9.33134878e-04],
#        [-3.56566468e+00,  7.31439222e-01,  3.10236995e+00, ...,
#         -1.42186219e-01, -1.20291402e-01, -3.46821991e-01],
#        ...,
#        [ 1.03770537e+01, -9.65676711e-01,  1.57343168e+00, ...,
#         -5.97585851e-01, -2.37006699e-02,  9.45619117e-01],
#        [ 9.66384871e+00, -1.02065521e+00,  1.20468889e+00, ...,
#         -7.24158801e-01, -2.62107599e-02,  7.23719250e-01],
#        [ 3.83682173e+00,  1.54974309e+00, -1.86263343e+00, ...,
#          1.50442411e+00, -4.23973090e-01, -3.79275284e-01]])

# %%
principalDf = pd.DataFrame(data = principalComponents)
principalDf.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -3.743386  0.671760  3.010733  1.770929  0.241249 -0.242314  0.428352
# 1 -4.521007 -0.380771  1.658844  1.144624  0.975353 -0.981376 -0.320455
# 2 -3.565665  0.731439  3.102370  1.875407  0.290381 -0.247928  0.468570
# 3 -3.659504  0.698511  3.052878  1.821137  0.265167 -0.246088  0.446728
# 4 -3.889817  0.631144  2.942587  1.679454  0.195817 -0.230389  0.399022
#
#          7         8         9         10        11        12        13  \
# 0 -0.220679 -0.395995  0.200789  0.633409  0.158802 -0.505039 -0.036088
# 1  0.221060  0.420854 -1.139052  1.067222  0.578279 -0.579806 -0.057625
# 2  0.007895 -0.505631  0.162414  0.738792  0.150681 -0.551032 -0.037551
# 3 -0.110198 -0.449640  0.180938  0.685175  0.155119 -0.527196 -0.036673
# 4 -0.425540 -0.293521  0.242891  0.534094  0.164556 -0.464505 -0.035629
#
#          14        15        16        17        18        19
# 0 -0.223397  0.720856  0.265852 -0.227835 -0.141072 -0.327781
# 1 -0.798584  1.217582  0.997198 -0.447220  0.394583  0.000933
# 2 -0.253779  0.755600  0.309213 -0.142186 -0.120291 -0.346822
# 3 -0.238047  0.738381  0.285902 -0.186558 -0.131728 -0.336542
# 4 -0.196922  0.685340  0.232262 -0.303120 -0.155718 -0.312917

# %%
DTClassifier= DecisionTreeRegressor (max_depth=50, min_samples_split =2)
DTClassifier.fit(principalDf,df_y)
predicted_labels = DTClassifier.predict(principalDf)
predicted_labels
# Out:
# array([24.43166667, 26.5       , 28.16666667, ...,  1.98      ,
#         1.84      , 12.1       ])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(df_y,predicted_labels)
# Out:
# 18.514249538204826

# %%
finalDf = pd.concat([principalDf,df["critical_temp"]],axis=1)

# %%
features1=finalDf.iloc[:,0:20]

label1 = np.array(finalDf["critical_temp"])

# %%
from sklearn.model_selection import train_test_split

X_train1, X_test1, y_train1, y_test1 = train_test_split(features1,label1, test_size=0.2, random_state=1)

# %%
DTClassifier= DecisionTreeRegressor (max_depth=50, min_samples_split =3,min_samples_leaf=5)
DTClassifier.fit(X_train1,y_train1)
predicted_labels = DTClassifier.predict(X_test1)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test1,predicted_labels)
# Out:
# 146.09159445654092
